# %% [markdown]
# # COMP9414 - Assignment 2 - Collaborative Multi-Agent Reinforcement Learning
# ### z5742721 - Troy Coleman

# %% [markdown]
# ### Overview
# The assignment is divided into 5 parts.
# - [Task 1: Multi-Agent Reinforcement Learning (MARL) Environment](#task-1)
#     - [1.1: Gridworld Implementation](#t-1-1)
#     - [1.2: Gridworld Visualization](#t-1-2)
#     - [1.3: Demonstration Script](#t-1-3)
#     - [1.4: Collision Verification](#t-1-4)
# - [Task 2: Modular PPO Pipeline Construction for Multi-Robot System](#task-2)
#     - [2.1: PPO Actor and Critic (Test & Code)](#t-2-1)
#     - [2.2: Rollout Buffer Module (Test & Code)](#t-2-2)
#     - [2.3: Advantage Estimator Module (Test & Code)](#t-2-3)
#     - [2.4: Optimizer Module (Test & Code)](#t-2-4)
# - [Task 3: Independant Proximal Policy Optimization](#task-3)
#     - [3.1: Source](#t-3-1)
#     - [3.2: IPPO Training Results](#t-3-2)
#     - [3.3: IPPO Performance Evaluation](#t-3-3)
#     - [3.4: IPPO Visual Demonstration](#t-3-4)
# - [Task 4: Multi-Agent Proximal Policy Optimization](#task-4)
#     - [4.1: Source](#t-4-1)
#     - [4.2: MAPPO Training Results](#t-4-2)
#     - [4.3: MAPPO Performance Evaluation](#t-4-3)
#     - [4.4: MAPPO Visual Demonstration](#t-4-4)
# - [Task 5: Comprehensive Evaluation](#task-5)
#     - [5.1: Generalization Analysis](#t-5-1)
#     - [5.2: Global Redunancy Coverage Ratio Map](#t-5-2)
#     - [5.3: Agents Contribution Anaylsis](#t-5-3)
#     - [5.4: Jensen-Shannon Divergence Pairwise Divergence Matrix](#t-5-4)

# %% [markdown]
# # <a id="task-1">Task 1: Multi-Agent Reinforcement Learning (MARL) Environment</a>

# %% [markdown]
# Summary: -> Summary of Task requirements

# %% [markdown]
# Subsections:
# - [1.1: Gridworld Implementation](#t-1-1)
# - [1.2: Gridworld Visualization](#t-1-2)
# - [1.3: Demonstration Script](#t-1-3)
# - [1.4: Collision Verification](#t-1-4)

# %% [markdown]
# ## <a id="t-1-1">1.1: Gridworld Implementation</a>

# %% [markdown]
# Implentation

# %%
#

# %% [markdown]
# ## <a id="t-1-2">1.2: Gridworld Visualization</a>

# %% [markdown]
# Visualization

# %%
#

# %% [markdown]
# ## <a id="t-1-3">1.3: Demonstration Script</a>

# %% [markdown]
# Demo

# %%
#

# %% [markdown]
# ## <a id="t-1-4">1.4: Collision Verification</a>

# %% [markdown]
# Verification

# %%
#

# %% [markdown]
# ## <a id="task-2">Task 2: Modular PPO Pipeline Construction for Multi-Robot System</a>

# %% [markdown]
# Summary: -> Summary of Task requirements

# %% [markdown]
# Subsections:
# - [2.1: PPO Actor and Critic (Test & Code)](#t-2-1)
# - [2.2: Rollout Buffer Module (Test & Code)](#t-2-2)
# - [2.3: Advantage Estimator Module (Test & Code)](#t-2-3)
# - [2.4: Optimizer Module (Test & Code)](#t-2-4)

# %% [markdown]
# ## <a id="t-2-1">2.1: PPO Actor and Critic (Test & Code)</a>

# %% [markdown]
# Actor and critic

# %%
#

# %% [markdown]
# ## <a id="t-2-2">2.2: Rollout Buffer Module (Test & Code)</a>

# %% [markdown]
# Buffer Module

# %%
#

# %% [markdown]
# ## <a id="t-2-3">2.3: Advantage Estimator Module (Test & Code)</a>

# %% [markdown]
# Estimator Module

# %%
#

# %% [markdown]
# ## <a id="t-2-4">2.4: Optimizer Module (Test & Code)</a>

# %% [markdown]
# Optimizer

# %%
#

# %% [markdown]
# ## <a id="task-3">Task 3: Independant Proximal Policy Optimization</a>

# %% [markdown]
# Summary: -> Summary of Task requirements

# %% [markdown]
# Subsections:
# - [3.1: Source](#t-3-1)
# - [3.2: IPPO Training Results](#t-3-2)
# - [3.3: IPPO Performance Evaluation](#t-3-3)
# - [3.4: IPPO Visual Demonstration](#t-3-4)

# %% [markdown]
# ## <a id="t-3-1">3.1: Source</a>

# %%
#

# %% [markdown]
# ## <a id="t-3-2">3.2: IPPO Training Results</a>

# %% [markdown]
# Training Results

# %%
#

# %% [markdown]
# ## <a id="t-3-3">3.3: IPPO Performance Evaluation</a>

# %% [markdown]
# Performance Evaluation

# %%
#

# %% [markdown]
# ## <a id="t-3-4">3.4: IPPO Visual Demonstration</a>

# %% [markdown]
# Visual Demonstration

# %% [markdown]
# ## <a id="task-4">Task 4: Multi-Agent Proximal Policy Optimization</a>

# %% [markdown]
# ## <a id="t-4-1">4.1: Source</a>

# %% [markdown]
# Summary: -> Summary of Task requirements

# %% [markdown]
# Subsections:
# - [1.1: Gridworld Implementation](#t-1-1)
# - [1.2: Gridworld Visualization](#t-1-2)
# - [1.3: Demonstration Script](#t-1-3)
# - [1.4: Collision Verification](#t-1-4)

# %%
#

# %% [markdown]
# ## <a id="t-4-2">4.2: MAPPO Training Results</a>

# %%
#

# %% [markdown]
# ## <a id="t-4-3">4.3: MAPPO Performance Evaluation</a>

# %%
#

# %% [markdown]
# ## <a id="t-4-4">4.4: MAPPO Visual Demonstration</a>

# %%
#

# %% [markdown]
# ## <a id="task-5">Task 5: Comprehensive Evaluation</a>

# %% [markdown]
# Summary: -> Summary of Task requirements

# %% [markdown]
# Subsections:
# - [1.1: Gridworld Implementation](#t-1-1)
# - [1.2: Gridworld Visualization](#t-1-2)
# - [1.3: Demonstration Script](#t-1-3)
# - [1.4: Collision Verification](#t-1-4)

# %% [markdown]
# ## <a id="t-5-1">5.1: Generalization Analysis</a>

# %%
#

# %% [markdown]
# ## <a id="t-5-2">5.2: Global Redunancy Coverage Ratio Map</a>

# %%
#

# %% [markdown]
# ## <a id="t-5-3">5.3: Agents Contribution Anaylsis</a>

# %%
#

# %% [markdown]
# ## <a id="t-5-4">5.4: Jensen-Shannon Divergence Pairwise Divergence Matrix</a>

# %%
#
